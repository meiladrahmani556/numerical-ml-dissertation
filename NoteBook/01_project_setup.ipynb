# %% [markdown]
# <a href="https://colab.research.google.com/github/meiladrahmani556/numerical-ml-dissertation/blob/main/NoteBook/01_project_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Project Setup & Dataset Selection

## A. Confirmed Project Scope

This project focuses on the application of machine learning methods to numerical data analysis, using an approved numerical dataset. The goal is to compare multiple supervised machine learning models on a real-world dataset to solve a prediction or classification problem.

This notebook provides the project plan and proposed dataset shortlist for discussion and approval.

# %%
## B. Project Plan Summary

### Aim
To evaluate and compare machine learning models on a numerical dataset using a structured data science workflow.

### Objectives
1. Prepare a formal project plan
2. Propose a shortlist of numerical datasets for discussion and approval
3. Perform exploratory data analysis (EDA)
4. Clean and preprocess numerical data
5. Develop baseline machine learning models
6. Improve model performance through tuning
7. Evaluate and compare models using performance metrics
8. Document conclusions and future work

# %%
## C. Proposed Numerical Dataset Shortlist

The following numerical datasets are proposed for discussion and approval:

1. **House Prices Dataset** – Regression (predict sale prices based on features)
2. **Wine Quality Dataset** – Classification / Regression (predict wine quality scores)
3. **Heart Disease Dataset** – Classification (predict presence of heart disease)
4. **Student Performance Dataset** – Classification / Regression (predict exam performance)
5. **Energy Efficiency Dataset** – Regression (predict heating/cooling load)

# %%
## D. Reasons for Shortlist Selection

- All datasets are **numerical in nature**
- Well-known, publicly available (e.g., UCI / Kaggle)
- Suitable for supervised learning tasks
- Include multiple features for meaningful EDA and model training
- Can be completed within the project timeline

# %%
## E. Next Steps

1. Supervisor to review and approve dataset choice
2. Load approved dataset into the project
3. Perform EDA and preprocessing
4. Train baseline machine learning models
5. Improve and evaluate models
