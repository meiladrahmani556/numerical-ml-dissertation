# %% [markdown]
# <a href="https://colab.research.google.com/github/meiladrahmani556/numerical-ml-dissertation/blob/main/NoteBook/02_dataset_selection_and_project_plan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset Selection and Project Plan
#
# ## 1. Project Overview
#
# This project focuses on the application of machine learning techniques to **numerical datasets** in order to analyse, model, and predict real-world phenomena.
#
# The project follows a structured data science workflow, including:
# - Dataset selection and justification
# - Exploratory Data Analysis (EDA)
# - Data preprocessing
# - Model development
# - Model evaluation and comparison
#
# This notebook documents the **project plan** and the **dataset selection process**, in line with university requirements and supervisor guidance.

# %% [markdown]
# ## 2. Project Objectives
#
# The main objectives of this project are:
#
# - To select an appropriate **numerical dataset** suitable for supervised machine learning
# - To perform exploratory analysis to understand feature relationships
# - To preprocess numerical data for modelling
# - To implement and compare multiple machine learning models
# - To evaluate model performance using appropriate quantitative metrics

# %% [markdown]
# ## 3. Project Plan and Timeline
#
# The project will be carried out according to the following plan:
#
# ### Phase 1: Dataset Selection and Planning
# - Identify suitable numerical datasets
# - Compare datasets and select the most appropriate one
# - Define project objectives and evaluation metrics
#
# ### Phase 2: Exploratory Data Analysis (EDA)
# - Summary statistics
# - Feature distributions
# - Correlation analysis
# - Identification of missing values and outliers
#
# ### Phase 3: Data Preprocessing
# - Handling missing data
# - Feature scaling and normalisation
# - Feature selection (if required)
# - Train–test split
#
# ### Phase 4: Model Development
# - Baseline model implementation
# - Advanced models (e.g. multiple regression, tree-based models)
# - Hyperparameter tuning
#
# ### Phase 5: Model Evaluation
# - Performance comparison using numerical metrics
# - Error analysis
# - Model interpretation
#
# ### Phase 6: Conclusions and Reporting
# - Summary of findings
# - Limitations
# - Recommendations for future work

# %% [markdown]
# ## 4. Dataset Selection Criteria
#
# To ensure suitability for the project, datasets were evaluated based on the following criteria:
#
# - Numerical nature of features
# - Sufficient dataset size
# - Real-world relevance
# - Suitability for supervised learning
# - Public availability and academic credibility

# %% [markdown]
# ## 5. Shortlist of Numerical Datasets
#
# ### Dataset 1: California Housing Prices
# - Source: Scikit-learn
# - Task: Regression
# - Description: Predict median house values based on numerical features such as income, population, and location statistics.
#
# ### Dataset 2: Energy Efficiency Dataset
# - Source: UCI Machine Learning Repository
# - Task: Regression
# - Description: Predict heating and cooling load of buildings based on numerical design parameters.
#
# ### Dataset 3: Wine Quality Dataset
# - Source: UCI Machine Learning Repository
# - Task: Classification or Regression
# - Description: Predict wine quality scores based on physicochemical properties.
#
# ### Dataset 4: Credit Card Default Dataset
# - Source: UCI Machine Learning Repository
# - Task: Classification
# - Description: Predict customer default based on financial and demographic numerical attributes.
#
# ### Dataset 5: Bike Sharing Demand Dataset
# - Source: Kaggle
# - Task: Regression
# - Description: Predict daily bike rental demand based on weather and seasonal numerical features.

# %% [markdown]
# ## 6. Selected Dataset and Justification
#
# **Selected Dataset:** California Housing Prices Dataset
#
# ### Justification:
# - Entirely numerical feature set
# - Widely used in academic machine learning studies
# - Suitable for regression modelling
# - Clear evaluation metrics (e.g. RMSE, MAE, R²)
# - Well-documented and easily reproducible
#
# This dataset aligns well with the project objectives and allows for meaningful model comparison and analysis.

# %%
# This cell ensures the environment is ready for future notebooks

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Environment setup complete.")
# Out:
# Environment setup complete.

# %% [markdown]
# ## 7. Next Steps
#
# The next stage of the project will focus on:
#
# - Loading the selected dataset
# - Performing Exploratory Data Analysis (EDA)
# - Visualising feature distributions and correlations
#
# These tasks will be implemented in **Notebook 03 – Exploratory Data Analysis**.
