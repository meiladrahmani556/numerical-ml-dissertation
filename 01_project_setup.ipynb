# %% [markdown]
# <a href="https://colab.research.google.com/github/meiladrahmani556/numerical-ml-dissertation/blob/main/01_project_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Project Setup and Scope

## Aim
The aim of this project is to apply machine learning techniques to numerical data in order to build and evaluate predictive models.

## Motivation
Numerical data is widely used in engineering, finance, and industrial applications. This project focuses on extracting insights and building reliable predictive models using such data.

## Planned Workflow
1. Dataset selection
2. Exploratory Data Analysis (EDA)
3. Data preprocessing
4. Baseline model development
5. Model improvement and optimisation
6. Model evaluation
# Out:
#   File "/tmp/ipython-input-2201835345.py", line 4
#     The aim of this project is to apply machine learning techniques to numerical data in order to build and evaluate predictive models.
#         ^
# SyntaxError: invalid syntax
